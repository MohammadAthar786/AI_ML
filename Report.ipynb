# %% [markdown]
# # Inspection of Dataset
# First of All i have inspect the Dataset to get the Basic overview and understanding of the dataset using inspect_data Method to get basic insight about dataset and understanding
#
# using the pandas function such as df.head(),df.tail(),df.shape(),df.info(),df.describe(),df.duplicated.sum(),df.isnull().sum()

# %% [markdown]
# # Perform EDA
#
# plot Heatmap of Missing value Count of Dataframe using sns.heatmap(data=df.isnull(),cbar=False,cmap=True)
# What i find that most missing values are in the column 'deck' then 'age' and very rare in 'embarked','embarked_town'
# missing value count in 'deck'col is greater than 50 percent and it coorelation with target feature 'survive'is also low so we can safely drop it from dataset
#
# Inference from EDA
# ->The count of People who died is more than who survive in the incident implies that rescue boats were few
#
# ->Most Number of people are from southhampton then from cherbourg then from Queenstown
#
# ->Most Number of Peoples are in Deck C and the order of People in Different Decks in Descneding order is C , B ,D ,E,A,F,G ,very few People were present in Deck G
#
# ->In the ship mostly were men , women also present but they were significantly lower than the men and children were also present but very lesser in number
#
# ->Most of the Peoples were in the Third Class of the Ship ,but the interesting is that more People are in the First class than second Class so order is Third class> First Class>Second Class
#
# ->Mean fare was around 30 pound or dollar
#
# ->Mean age of the People were around 28-29 years
#
# ->Mostly Female Survived, Men Survived ver less compared to Women
#
# ->Mostly First Class people were Survived most compared to third class although more number of peoples are in Third class implies that First Class people were likely  given most priority for rescue boat
#
# ->Women Survived more than even Children but very few man survived implies that most Probabily Women is given more Priority for boarding in Rescue boats , then children and men has given least priority for boarding in Rescue Boats
#
# ->Most People that died are from the Deck A of the Ship implies that most probably water breached the deck A first or impact of the Ship by the glacier is towards the side of Deck A,
# the people present in Deck B,D,E survived the most and people in all these Deck B,D ,E survived equally
#
# ->Most people that survived are from Cherbourg,although most People were from Southhampton indicating that probabibly most people from cherbourg were Women or are Present in First Class
#
# from BoxPlot of pclass vs Survived
#
# Higher-class passengers (Pclass = 1) were more likely to survive.
#
# Lower-class passengers (Pclass = 3) were less likely to survive.
#
# Socioeconomic status (class) significantly influenced survival chances.
#
# from the BoxPlot od age vs survivor
#
# Median age is slightly lower for survivors (~28) than for non-survivors (~29).
#
# The IQR is slightly lower for survivors.
#
# A few very old survivors are visible as outliers (~60–80).
#
# Age ranges are fairly similar but survivors include more younger children.
#
# Inference:
#
# There is no extreme age difference, but:
#
# Children (young passengers) had a better survival rate.
#
# Age might have a slight impact, especially for younger passengers.
#
# from the BoxPlot of SibSp by Survived
#
# Observation:
#
# Both survivors and non-survivors mostly had SibSp = 0 or 1.
#
# There are outliers for non-survivors (SibSp up to 8).
#
# Survivors with SibSp rarely exceed 2.
#
# Inference:
#
# Passengers with 1 or 2 siblings/spouses had higher chances of survival.
#
# Very high values of SibSp (large families) are associated with lower survival.
#
# Being alone or in a very large group was a disadvantage.
